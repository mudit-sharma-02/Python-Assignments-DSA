# %% [markdown]
# # This is 1st level heading

# %% [markdown]
# ## This is my 2nd level heading

# %% [markdown]
# ### This is my 3rd level heading

# %% [markdown]
# I am doing my python class today.

# %%
# This function is created by Shreya and it is doing addditons of 2 variables

# %%
# This function is created by Shreya

# %%
"""
Date: 17th Aug 2024
Written by: Shreya Chittranshi
Purpose: Adding 2
"""
# Out:
# '\nDate: 17th Aug 2024\nWritten by: Shreya Chittranshi\nPurpose: Adding 2 \n'

# %%
#Date: 17th Aug 20224
#Written by: Shreya
#Purpose: Adding 2

# %%
a="This is my first python class"

# %%
print(a)
# Out:
# This is my first python class

# %%
a
# Out:
# 'This is my first python class'

# %%
a=1

# %%
print(a)
# Out:
# 1

# %%
print("a")
# Out:
# a

# %%
b=1
print(b)
# Out:
# 1

# %%
print("This is my first python class")
# Out:
# This is my first python class

# %%
A=7
a=6
c=A+a
print (A,a)
print ("my A value is:",A," my a value is:",a, "and the sum of A and a is", c)
# Out:
# 7 6
# my A value is: 7  my a value is: 6 and the sum of A and a is 13

# %%
print("a")
# Out:
# a

# %%
a=5
b=5.6
c="Hello"
d=True

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# float

# %%
type(c)
# Out:
# str

# %%
type(d)
# Out:
# bool

# %%
#Python Operators
#Arithmetic
#Comparison
#Assignment
#Logical
#Membership
#Identity

# %% [markdown]
# # Arithmetic Operator +,-,*,/,//,%,**

# %%
#Addition
x=6
y=5
r=x+y
print(r)
# Out:
# 11

# %%
#Addition
x=6
y=5
print(x+y)
# Out:
# 11

# %%
#Subtraction
x=6
y=5
r=x-y
print(r)
# Out:
# 1

# %%
#Multiplication
x=6
y=5
r=x*y
print(r)
# Out:
# 30

# %%
#Normal Division (/) --> (Float div)
x=10
y=5
r=x/y
print(r)
# Out:
# 2.0

# %%
type(r)
# Out:
# float

# %%
# Modulo Division (//) --> Floor Division --> without decimal values
x=10
y=5
res=x//y
print(res)
# Out:
# 2

# %%
# Remainder Division (%)
x=10
y=3
res=x%y
print(res)
# Out:
# 1

# %%
#Exponentiation (**)
res=x**y
print(res)
# Out:
# 1000

# %%
x=9
y=9
print(x+y)
# Out:
# 18

# %% [markdown]
# # Comparison Operators <,<=,>,>=,==,!=

# %% [markdown]
# # Comparison

# %%
a = 16
b = 15
print(a > b)
# Out:
# True

# %%
a = 16
b = 15
print(a < b)
# Out:
# False

# %%
a = 15
b = 15
print(a >= b)
# Out:
# True

# %%
# is equal to
# a == b is False
print(a == b)
# Out:
# False

# %%
a = 15
b = 16
print(a != b)
# Out:
# True

# %% [markdown]
# # Assignment Operator =,+=,*=,%=

# %%
a = 21
b = 10
c = a + b
print (c)
# Out:
# 31

# %%
c += a
#--> c=c+a
print (c)
# Out:
# 52

# %%
c *= a
#c=c*a
print (c)
# Out:
# 1092

# %%
a=4
c=10
c %= a
#c=c/a --> Remainder
print (c)
# Out:
# 2

# %%
a=4
c=10
c /=a
# c=c/a
print(c)
# Out:
# 2.5

# %% [markdown]
# # Logical Operator and, or, not

# %%
x = 5
y = 6
print(x < 3 and x < 10)
# Out:
# False

# %%
x = 5
y = 6
print(x > 3 and x < 2)
# Out:
# True

# %%
x = 5
y = 6
print(x < 3 or x < 10)
# Out:
# True

# %%
a = True
b = False

# Print a and b is False
print(a and b)

# Print a or b is True
print(a or b)

# Print not a is False
print(not b)
# Out:
# False
# True
# True

# %%
a=5
b=10
c=12
print(a<10 or (b>10 or c<10))
# Out:
# True

# %%
a=5
b=10
c=12
print(a<10 and (b>10 or c<10))
# Out:
# True

# %%
Print("Hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 Print("Hello")
#
# NameError: name 'Print' is not defined

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# # Membership Operator- in, not in

# %%
x = 'IIT Academy'
print('Cad' in x)
# Out:
# False

# %%
print('I' in x)
# Out:
# True

# %%
print('IIT' in x)
# Out:
# True

# %%
print('IIT' not in x)
# Out:
# False

# %%
print('Aca' not in x)
# Out:
# False

# %% [markdown]
# # Identity Operator is , is not

# %%
a1 = 3
b1 = 6
print(a1 is not b1)
# Out:
# True

# %%
print(a1 is b1)
# Out:
# False

# %%
a2 = 'IITACADEMY'
b2 = 'iitacademy'

# %%
print(a2 is b2)
# Out:
# False

# %%
print(a2 is not b2)
# Out:
# True

# %% [markdown]
# ### Order of Operators

# %%
a=30
b=10
c=20
d=5
e=(a+b)*c/d
print(e)
# Out:
# 160.0

# %% [markdown]
# # other commands

# %%
pwd()
# Out:
# 'C:\\Users\\hp\\Music\\Python Basics\\New folder\\Updated'

# %%
#Help
# ?print

# %%
#Dealing with Dates
import datetime as dt

# %%
# Print current date and time
dt.datetime.now()
# Out:
# datetime.datetime(2024, 8, 18, 18, 29, 58, 917166)

# %%
# Returns the current local date
dt.date.today()
# Out:
# datetime.date(2024, 8, 18)

# %%
#Creating Specific Date and Time Objects

date1=dt.datetime(2024, 8, 18, 10, 30)
print(date1)
# Out:
# 2024-08-18 10:30:00

# %%
date1=dt.date(2024, 8, 18)
print(date1)
# Out:
# 2024-08-18

# %%
time1=dt.time(10, 30, 0)
print(time1)
# Out:
# 10:30:00

# %%
#strfttime - Convert Date into string format
now = dt.datetime.now()
print(now)
t = now.strftime("%H:%M:%S")
print("time:", t)
# Out:
# 2024-08-18 18:38:29.300470
# time: 18:38:29

# %%
# Change the format of date
s1 = now.strftime("%m/%d/%Y, %H:%M:%S")
print(s1)
# Out:
# 08/18/2024, 18:38:29

# %%
#Extracting date and time components

now = datetime.now()
print(now)
print(now.year)
print(now.month)
print(now.day)
print(now.hour)
print(now.minute)
print(now.second)
# Out:
# 2024-08-18 18:39:45.764946
# 2024
# 8
# 18
# 18
# 39
# 45

# %%
# Comparing different dates

dt1 = datetime(2024, 8, 20, 10, 30)
dt2 = datetime(2024, 8, 19, 10, 30)
print(dt1)
print(dt2)
print(dt1 < dt2)
# Out:
# 2024-08-20 10:30:00
# 2024-08-19 10:30:00
# False
